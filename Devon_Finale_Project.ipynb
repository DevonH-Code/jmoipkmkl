# %% [markdown]
# <a href="https://colab.research.google.com/github/DevonH-Code/jmoipkmkl/blob/main/Devon_Finale_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Code Structure

# %%
import math
# Defines functions for basic arithmetic operations:
def add(a, b): #Function to add two numbers.
    return a + b

def subtract(a, b): #Function to subtract two numbers.
    return a - b

def multiply(a, b): #Function to multiply two numbers.
    return a * b

def divide(a, b): #Function to divide two numbers.
    if b == 0:
        raise ValueError("Division by zero")
    return a / b

def power(a, b): #Function to raise a number to a power.
    return a ** b

def square_root(a): #Function to calculate the square root of a number.
    if a < 0:
        raise ValueError("Square root of negative number")
    return math.sqrt(a)

def calculator(): # Function to create a simple calculator interface.
    #Creates a simple calculator interface that allows the user to perform. basic arithmetic operations.
    while True:
        print("Select operation:")
        print("1. Add")
        print("2. Subtract")
        print("3. Multiply")
        print("4. Divide")
        print("5. Power")
        print("6. Square Root")
        print("7. Exit")

        choice = input("Enter choice (1/2/3/4/5/6/7): ")

        if choice == '7':
            break

        if choice in ('1', '2', '3', '4', '5', '6'):
            try:
                num1 = float(input("Enter first number: "))
                if choice == '6':
                    result = square_root(num1)
                else:
                    num2 = float(input("Enter second number: "))
                    if choice == '1':
                        result = add(num1, num2)
                    elif choice == '2':
                        result = subtract(num1, num2)
                    elif choice == '3':
                        result = multiply(num1, num2)
                    elif choice == '4':
                        result = divide(num1, num2)
                    elif choice == '5':
                        result = power(num1, num2)

                print("Result:", result)
            except ValueError as e:
                print("Error:", e)
        else:
            print("Invalid input")

if __name__ == "__main__":
    calculator()
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Power
# 6. Square Root
# 7. Exit
# Enter choice (1/2/3/4/5/6/7): 1
# Enter first number: 2
# Enter second number: 3
# Result: 5.0
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Power
# 6. Square Root
# 7. Exit
# Enter choice (1/2/3/4/5/6/7): 1
# Enter first number: -2
# Enter second number: 3
# Result: 1.0
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Power
# 6. Square Root
# 7. Exit
# Enter choice (1/2/3/4/5/6/7): 1
# Enter first number: 2
# Enter second number: -3
# Result: -1.0
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Power
# 6. Square Root
# 7. Exit
# Enter choice (1/2/3/4/5/6/7): 2
# Enter first number: 5
# Enter second number: 3
# Result: 2.0
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Power
# 6. Square Root
# 7. Exit
# Enter choice (1/2/3/4/5/6/7): 2
# Enter first number: -5
# ...

# %% [markdown]
# ###Test Cases

# %% [markdown]
# Addition:
#
# (2, 3) = 5 (comfirmed)
#
# (-2, 3) = 1 (comfirmed)
#
# (2, -3) = -1 (comfirmed)

# %% [markdown]
# Subtraction:
#
# (5, 3) = 2 (comfirmed)
#
# (-5, 3) = -8 (comfirmed)
#
# (5, -3) = -6 (comfirmed)

# %% [markdown]
# Multiply:
#
# ```
# 1: self.assertEqual(multiply(2, 3), 6)
# 2: self.assertEqual(multiply(-2, 3), -6)
# 3: self.assertEqual(multiply(2, -3), -6)
# ```
# 1: 6 (Confirmed)
#
# 2: -6 (Confirmed)
#
# 3: -6 (Confirmed)

# %% [markdown]
# Division:
#
# ```
# 1: self.assertEqual(divide(6, 3), 2)
# 2: self.assertEqual(divide(-6, 3), -2)
# 3: self.assertEqual(divide(6, -3), -2)
# ```
# 1: 2 (Confirmed)
#
# 2: -2 (Confirmed)
#
# 3: -2 (Confirmed)

# %% [markdown]
# Power:
#
# ```
# 1: self.assertEqual(power(2, 3), 8)
# 2: self.assertEqual(power(-2, 3), -8)
# 3: self.assertEqual(power(2, -3), 0.125)
# ```
# 1: 8 (Confirmed)
#
# 2: -8 (Confirmed)
#
# 3: 0.125 (Confirmed)

# %% [markdown]
# Square Root:
#
# ```
# 1: self.assertEqual(square_root(4), 2)
# 2: self.assertEqual(square_root(-4), Error)
# ```
# 1: 2 (Confirmed)
#
# 2: Error (Confirmed)

# %% [markdown]
# ### Analysis

# %% [markdown]
# **Reflect:** Functions helped simplify the code structure, making it easier to read and more organized. It's also easier to debug and maintain, so finding the issues wouldn't be hard.
#
# **Discuss:** One way I can improve the code is by adding more operations, such as sin, cos, and tan, making the calculator more versatile.
